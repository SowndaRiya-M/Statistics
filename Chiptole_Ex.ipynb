# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Assign it to a variable called chipotle.

# %%
chi=pd.read_csv('chipotle.tsv',sep='\t')
chi
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
chi.groupby(level=0).sum()
chi
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pp=pd.read_csv('Indian_cities.csv')
pp
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
pp.groupby(level=).mean()
# Out:
#      state_code  dist_code  population_total  population_male  \
# 0             3          9            145238            76840
# 1            27          7            112293            58256
# 2            28          1            117388            59232
# 3            20         24            173988            91495
# 4            28         21            166537            82743
# ..          ...        ...               ...              ...
# 488          28         12            227533           111596
# 489          28          9            620116           310400
# 490          27          8            105543            53241
# 491           6          3            216628           115404
# 492          27         14            116714            58717
#
#      population_female  0-6_population_total  0-6_population_male  \
# 0                68398                 15870                 8587
# 1                54037                 11810                 6186
# ...

# %% [markdown]
# ### Step 3. See the first 10 entries

# %%
chi.head(10)
# Out:
# 0     2.39
# 1     3.39
# 2     3.39
# 3     2.39
# 4    16.98
# 5    10.98
# 6     1.69
# 7    11.75
# 8     9.25
# 9     9.25
# Name: item_price, dtype: float64

# %% [markdown]
# ### Step 4. What is the number of observations in the dataset?

# %%
chi.shape[0]
# Out:
# 4622

# %% [markdown]
# ### Step 5. What is the number of columns in the dataset?

# %%
chi.shape[1]
# Out:
# 5

# %% [markdown]
# ### Step 6. Print the name of all the columns.

# %%
chi.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# ### Step 7. Which was the most-ordered item?

# %%
print(chi.columns)
chi.groupby('item_name')[['quantity']].sum().sort_values('quantity',ascending=False)[:1]
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')
#               quantity
# item_name
# Chicken Bowl       761

# %% [markdown]
# ### Step 8. What was the most ordered item in the choice_description column?

# %%
chi.groupby('choice_description')[['quantity']].sum().sort_values('quantity',ascending=False)[:1]
# Out:
#                     quantity
# choice_description
# [Diet Coke]              159

# %% [markdown]
# ### Step 9. How many items were orderd in total?

# %%
chi['quantity'].sum()
# Out:
# 4972

# %% [markdown]
# ### Step 10. How much was the revenue for the period in the dataset?

# %%
#important df_start['AmountInUSD']=df_start['AmountInUSD'].apply(lambda x:float(str(x).replace(",","")))
def dollar(x):
    return float(x[1:-1])
chi['item_price']=chi['item_price'].apply(dollar)
revenue=(chi['quantity']*chi['item_price'])
revenue.sum()
# Out:
# 39237.02

# %% [markdown]
# ### Step 11. How many orders were made in the period?

# %%
chi.shape[0]
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %% [markdown]
# ### Step 12. How many different items are sold?

# %%
len(chi['item_name'].value_counts())
# Out:
# 50

# %%
len(chi['order_id'].value_counts())
# Out:
# 1834

# %%
Data Engineering - 50 marks

Q1) What percentage of medical schools admit between 51 and 60 percent of students? 
Q2) For how many schools is the 75th percentile ACT score more than 27? 
Q3) State the IDs of the top 5 and worst 5 schools. 
Q4) What is the average percentage of White students enrolled in the 10 schools with the highest percentage of women enrolled? 
Q5) What is the percentage chance of a women white student with a ACT composite score of 30 of getting admitted into the school with ID 226471? 
Q6) Reduce this set to 20 cheapest schools which meet the following criteria -
1) SCORE is in the top 25%
2) Percentage of women enrolled is more than 40%

# %%
ex.columns
# Out:
# Index(['ID number', 'Med_School_Acceptance', 'Med_School_Existence',
#        'ACT Composite 75th percentile score', 'Percent admitted - total',
#        'Total price for out-of-state students living on campus 2013-14',
#        'Percent of total enrollment that are White',
#        'Percent of total enrollment that are women',
#        'Percent of freshmen receiving any financial aid',
#        'Degrees to Enrollment', 'ACT Composite 75th percentile score.1',
#        'Percent admitted - total.1',
#        'Total price for out-of-state students living on campus 2013-14.1',
#        'Percent of total enrollment that are White.1',
#        'Percent of total enrollment that are women.1',
#        'Percent of freshmen receiving any financial aid.1',
#        'Degrees to Enrollment.1', 'SCORE'],
#       dtype='object')

# %%
#Q1) What percentage of medical schools admit between 51 and 60 percent of students? 
ex[ex['Percent admitted - total'].between(51,60)].head()
# Out:
#     ID number  Med_School_Acceptance  Med_School_Existence  \
# 2    136172.0                  0.633                   0.0
# 4    134097.0                  0.653                   0.0
# 13   102368.0                  0.101                   0.0
# 16   104179.0                  0.700                   0.0
# 17   175856.0                  0.599                   0.0
#
#     ACT Composite 75th percentile score  Percent admitted - total  \
# 2                                  24.0                      56.0
# 4                                  28.0                      56.0
# 13                                 25.0                      55.0
# 16                                 27.0                      52.0
# 17                                 27.0                      60.0
#
#     Total price for out-of-state students living on campus 2013-14  \
# 2                                             42740.0
# 4                                             48195.0
# ...

# %%
#Q2) For how many schools is the 75th percentile ACT score more than 27? 
len(ex[ex['ACT Composite 75th percentile score']>27])
# Out:
# 186

# %%
#Q3) State the IDs of the top 5 and worst 5 schools.
print("TOP 5")
print(ex.sort_values('SCORE',ascending=False)['ID number'].head())
print('WORST 5')
print(ex.sort_values('SCORE',ascending=True)['ID number'].head())
# Out:
# TOP 5
# 316    154350.0
# 96     229814.0
# 46     110583.0
# 439    239080.0
# 18     175421.0
# Name: ID number, dtype: float64
# WORST 5
# 80     110608.0
# 332    230728.0
# 357    167996.0
# 456    210429.0
# 11     228431.0
# Name: ID number, dtype: float64

# %%
#Q4) What is the average percentage of White students enrolled in the 10 schools with the highest percentage of women nrolled? 
ex2.columns
# Out:
# Index(['ID number', 'Med_School_Acceptance', 'Med_School_Existence',
#        'ACT Composite 75th percentile score', 'Percent admitted - total',
#        'Total price for out-of-state students living on campus 2013-14',
#        'Percent of total enrollment that are White',
#        'Percent of total enrollment that are women',
#        'Percent of freshmen receiving any financial aid',
#        'Degrees to Enrollment', 'ACT Composite 75th percentile score.1',
#        'Percent admitted - total.1',
#        'Total price for out-of-state students living on campus 2013-14.1',
#        'Percent of total enrollment that are White.1',
#        'Percent of total enrollment that are women.1',
#        'Percent of freshmen receiving any financial aid.1',
#        'Degrees to Enrollment.1', 'SCORE'],
#       dtype='object')

# %%
a=ex2.groupby(['Percent of total enrollment that are women','ID number'])[['Percent of total enrollment that are White']].mean()
a.sort_values('Percent of total enrollment that are White',ascending=False).head(10)
# Out:
#                                                       Percent of total enrollment that are White
# Percent of total enrollment that are women ID number
# 36.0                                       169910.0                                         90.0
# 61.0                                       182670.0                                         89.0
# 59.0                                       143084.0                                         88.0
# 53.0                                       154350.0                                         87.0
# 55.0                                       129525.0                                         86.0
# 64.0                                       178411.0                                         84.0
# 57.0                                       149222.0                                         83.0
# 59.0                                       118693.0                                         83.0
# ...

# %% [markdown]
# Q5) What is the percentage chance of a women white student with a ACT composite score of 30 of getting admitted into the school with ID 226471?

# %%
ex1=pd.read_excel('Dataset for Test 3.xlsx')
a=ex1[ex1['ID number']==226471]
total=len(a[a['ACT Composite 75th percentile score']<=30])
print((total/ex1.shape[0])*100)
# Out:
# 0.20833333333333334

# %%
a=ex2[ex2['ID number']==226471]
a
# Out:
#    ID number  Med_School_Acceptance  Med_School_Existence  \
# 8   226471.0                  0.932                   0.0
#
#    ACT Composite 75th percentile score  Percent admitted - total  \
# 8                                 27.0                      68.0
#
#    Total price for out-of-state students living on campus 2013-14  \
# 8                                            44287.0
#
#    Percent of total enrollment that are White  \
# 8                                        86.0
#
#    Percent of total enrollment that are women  \
# 8                                        55.0
#
#    Percent of freshmen receiving any financial aid  Degrees to Enrollment  \
# 8                                            100.0                    0.0
#
#    ACT Composite 75th percentile score.1  Percent admitted - total.1  \
# 8                               6.190476                    11.87234
#
#    Total price for out-of-state students living on campus 2013-14.1  \
# ...

# %%
ex2.columns
# Out:
# Index(['ID number', 'Med_School_Acceptance', 'Med_School_Existence',
#        'ACT Composite 75th percentile score', 'Percent admitted - total',
#        'Total price for out-of-state students living on campus 2013-14',
#        'Percent of total enrollment that are White',
#        'Percent of total enrollment that are women',
#        'Percent of freshmen receiving any financial aid',
#        'Degrees to Enrollment', 'ACT Composite 75th percentile score.1',
#        'Percent admitted - total.1',
#        'Total price for out-of-state students living on campus 2013-14.1',
#        'Percent of total enrollment that are White.1',
#        'Percent of total enrollment that are women.1',
#        'Percent of freshmen receiving any financial aid.1',
#        'Degrees to Enrollment.1', 'SCORE'],
#       dtype='object')

# %%
Q6) Reduce this set to 20 cheapest schools which meet the following criteria -
1) SCORE is in the top 25%
2) Percentage of women enrolled is more than 40%
# Out:
#   File "<ipython-input-104-9b48fd5d4b14>", line 1
#     Q6) Reduce this set to 20 cheapest schools which meet the following criteria -
#       ^
# SyntaxError: invalid syntax

# %%
ex.shape
# Out:
# (480, 2)

# %%
#Q5) What is the percentage chance of a women white student with a ACT composite score of 30 of getting admitted into the school with ID 226471? 
ex2=ex2[['Percent of total enrollment that are White','ACT Composite 75th percentile score']]
ex2[ex2['ACT Composite 75th percentile score']<=30]
stu=len(ex2['Percent of total enrollment that are White'])
tot=ex.shape[0]
print((stu/tot)*100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d84308bfa74f> in <module>
#       1 #Q5) What is the percentage chance of a women white student with a ACT composite score of 30 of getting admitted into the school with ID 226471?
# ----> 2 ex2=ex2[['Percent of total enrollment that are White','ACT Composite 75th percentile score']]
#       3 ex2[ex2['ACT Composite 75th percentile score']<=30]
#       4 stu=len(ex2['Percent of total enrollment that are White'])
#       5 tot=ex.shape[0]
#
# NameError: name 'ex2' is not defined

# %%
import pandas as pd
ex2=pd.read_excel('Dataset for Test 3.xlsx')
ex2
# Out:
#      ID number  Med_School_Acceptance  Med_School_Existence  \
# 0     227526.0                  0.526                   0.0
# 1     160658.0                  0.647                   0.0
# 2     136172.0                  0.633                   0.0
# 3     228778.0                  0.336                   0.0
# 4     134097.0                  0.653                   0.0
# ..         ...                    ...                   ...
# 475   173124.0                  1.045                   0.0
# 476   236577.0                  0.114                   0.0
# 477   237066.0                  0.545                   0.0
# 478   200280.0                  0.472                   0.0
# 479        NaN                    NaN                   NaN
#
#      ACT Composite 75th percentile score  Percent admitted - total  \
# 0                                   27.0                      49.0
# 1                                   24.0                      68.0
# ...

# %%
ex2=ex2.sort_values('SCORE',ascending=False).head(20)
ex2[ex2['Percent of total enrollment that are women']>40.0]

#ex2[(ex2['SCORE'].between(68.823966,57.864092))&(ex2['Percent of total enrollment that are women']>40)]
# Out:
#      ID number  Med_School_Acceptance  Med_School_Existence  \
# 316   154350.0                  0.438                   0.0
# 96    229814.0                  0.725                   0.0
# 46    110583.0                  0.270                   0.0
# 439   239080.0                  0.291                   0.0
# 18    175421.0                  1.100                   0.0
# 161   149222.0                  0.543                   0.0
# 97    198543.0                  0.523                   0.0
# 438   182670.0                  0.634                   0.0
# 294   191241.0                  0.317                   0.0
# 336   129525.0                  0.584                   0.0
# 171   178411.0                  0.643                   0.0
# 322   143084.0                  0.213                   0.0
# 270   211431.0                  0.386                   0.0
# 346   148496.0                  0.586                   0.0
# 355   167260.0                  0.675                   0.0
# ...

# %%
#Q1) What percentage of medical schools admit between 51 and 60 percent of students? 
ex[ex['Percent admitted - total'].between(51,60)].head()
#Q2) For how many schools is the 75th percentile ACT score more than 27? 
len(ex[ex['ACT Composite 75th percentile score']>27])
#Q3) State the IDs of the top 5 and worst 5 schools.
print("TOP 5")
print(ex.sort_values('SCORE',ascending=False)['ID number'].head())
print('WORST 5')
print(ex.sort_values('SCORE',ascending=True)['ID number'].head())
#Q4) What is the average percentage of White students enrolled in the 10 schools with the highest percentage of women enrolled? 
a=ex2.groupby(['Percent of total enrollment that are women','ID number'])[['Percent of total enrollment that are White']].mean()
a.sort_values('Percent of total enrollment that are White',ascending=False).head(10)
#Q5) What is the percentage chance of a women white student with a ACT composite score of 30 of getting admitted into the school with ID 226471? 
ex2=ex2[['Percent of total enrollment that are White','ACT Composite 75th percentile score','SCORE','ID number']]
ex2=ex2[ex2['ID number']==226471]
ex2[ex2['ACT Composite 75th percentile score']==30]
stu=len(ex2['Percent of total enrollment that are White'])
print(stu)
tot=480
print((stu/tot)*100)
#Q6) Reduce this set to 20 cheapest schools which meet the following criteria -
#1) SCORE is in the top 25%
#2) Percentage of women enrolled is more than 40%
ex2=ex2.sort_values('SCORE',ascending=False).head(20)
ex2[ex2['Percent of total enrollment that are women']>40.0]
# Out:
#   File "<ipython-input-108-fa4641e28ac8>", line 15
#     ex2[ex2['ACT Composite 75th percentile score']=30]
#                                                   ^
# SyntaxError: invalid syntax

# %%
#Q1) What percentage of medical schools admit between 51 and 60 percent of students? 
aa=ex2[ex2['Percent admitted - total'].between(51,60)]
print((aa.shape[0]/ex2.shape[0])*100)
print(aa.shape[0])
# Out:
# 18.541666666666668
# 89

# %%
len(ex2[ex2['ACT Composite 75th percentile score']>27])
# Out:
# 186

# %%
print("TOP 5")
print(ex2.sort_values('SCORE',ascending=False)['ID number'].head())
print('WORST 5')
print(ex2.sort_values('SCORE',ascending=True)['ID number'].head())
# Out:
# TOP 5
# 316    154350.0
# 96     229814.0
# 46     110583.0
# 439    239080.0
# 18     175421.0
# Name: ID number, dtype: float64
# WORST 5
# 80     110608.0
# 332    230728.0
# 357    167996.0
# 456    210429.0
# 11     228431.0
# Name: ID number, dtype: float64

# %%
ex2=ex2[['Percent of total enrollment that are White','ACT Composite 75th percentile score','SCORE','ID number']]
ex2=ex2[ex2['ID number']==226471]
ex2[ex2['ACT Composite 75th percentile score']==30]

stu=len(ex2['Percent of total enrollment that are White'])
print(stu)
tot=480
print((stu/tot)*100)
# Out:
# 1
# 0.20833333333333334

# %%
ex2=pd.read_excel('Dataset for Test 3.xlsx')
ex2
# Out:
#      ID number  Med_School_Acceptance  Med_School_Existence  \
# 0     227526.0                  0.526                   0.0
# 1     160658.0                  0.647                   0.0
# 2     136172.0                  0.633                   0.0
# 3     228778.0                  0.336                   0.0
# 4     134097.0                  0.653                   0.0
# ..         ...                    ...                   ...
# 475   173124.0                  1.045                   0.0
# 476   236577.0                  0.114                   0.0
# 477   237066.0                  0.545                   0.0
# 478   200280.0                  0.472                   0.0
# 479        NaN                    NaN                   NaN
#
#      ACT Composite 75th percentile score  Percent admitted - total  \
# 0                                   27.0                      49.0
# 1                                   24.0                      68.0
# ...
