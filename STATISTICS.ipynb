# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import cufflinks as cf
from scipy import stats
import wquantiles
import statsmodels
import statsmodels.robust.scale
py.offline.init_notebook_mode(connected=True)
cf.go_offline()
import sklearn
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
106	7
100	27
86	2
101	50
99	28
103	29
97	20
113	12
112	6
110	17

# %%
data = {'x':  [106,100,86,101,99,103,97,113,112,110],
        'y': [7,27,2,50,28,29,20,12,6,17]}

df = pd.DataFrame (data, columns = ['x','y'])
correlation    = df.corr(method='pearson')
correlation
# Out:
#           x         y
# x  1.000000 -0.070216
# y -0.070216  1.000000

# %%
pd.DataFrame()

# %%
a=pd.Series([4,20,5,21,54,99,64,48])
a.quantile(0.75)
# Out:
# 56.5

# %%
Create an array of fixed size (maximum capacity), lets say 10.
2. Take n, a variable which stores the number of elements of the array, less than maximum capacity of array.
3. Iterate via for loop to take array elements as input, and print them.
4. The array elements are in unsorted fashion, to sort them, make a nested loop.
5. In the nested loop, the each element will be compared to all the elements below it.
6. In case the element is greater than the element present below it, then they are interchanged
7. After executing the nested loop, we will obtain an array in ascending order arranged elements.

# %%
Declare and initialize an array.
Loop through the array and select an element.
The inner loop will be used to compare the selected element from the outer loop with the rest of the elements of the array.
If any element is less than the selected element then swap the values.
Continue this process till entire array is sorted in ascending order.

# %%
a=[5,6,2,3,4]
for i in range(len(a)):
    for j in range(i+1,len(a)):
        if a[i]>a[j]:
            temp=a[i]
            a[i]=a[j]
            a[j]=temp
print(a[i])
# Out:
# 5
# 2
# 3
# 2

# %%
a=2
b=3
c=4

# %%
a,b,c=c,b,a

# %%
print(a,b,c)
# Out:
# 4 3 2

# %%
pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1320 sha256=72a0af4d555fc910a53a21e5920223b6eb3f7af04f7e95cc6c8b5b44f144d891
#   Stored in directory: c:\users\sowndariya\appdata\local\pip\cache\wheels\46\ef\c3\157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install  statsmodels
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wquantiles
# Out:
# ...
#   Created wheel for wquantiles: filename=wquantiles-0.5-py3-none-any.whl size=2513 sha256=f8544ec645266482e4fb0a28af4fe461dc3cb84d78e5ffbbbb16bddef45da296
#   Stored in directory: c:\users\sowndariya\appdata\local\pip\cache\wheels\c7\36\83\d57269027febb66f432e4f578ed118910b15d8bd49ae67ad1f
# Successfully built wquantiles
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('Indian_cities.csv')
df
# Out:
#       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
df[['population_total']].mean()
# Out:
# population_total    448112.373225
# dtype: float64

# %% [markdown]
# Here is how we compute a 20% trimmed mean.
#
# Let’s consider a sample of 20 observations:
#
# 39 92 75 61 45 87 59 51 87 12  8 93 74 16 32 39 87 12 47 50
#
# First we sort them:
#
# 8 12 12 16 32 39 39 45 47 50 51 59 61 74 75 87 87 87 92 93
#
# The number of observations to remove is floor(0.2 * 20) = 4. So we trim 4 observations from each end:
#
# (8 12 12 16) 32 39 39 45 47 50 51 59 61 74 75 87 (87 87 92 93)
#
# And we take the mean of the remaining observations, such that our 20% trimmed mean = mean(c(32,39,39,45,47,50,51,59,61,74,75,87)) = 54.92

# %%
#trim_mean
stats.trim_mean((8, 12, 12,16,32,39,39,45,47,50,51,59,61,74,75,87,87,87,92,93),0.2)
# Out:
# 54.916666666666664

# %%
stats.trim_mean(df['population_total'],0.1)
# Out:
# 248547.94683544303

# %%
#weighted_median
np.average(df['population_male'],weights=(df['population_total']))
wquantiles.median(df['population_male'], weights=(df['population_total']))
# Out:
# 525179.7422105328

# %%
#standard deviation,MAD,IQR
stdd=df['population_total'].std()
iqr=df['population_total'].quantile(0.75) - df['population_total'].quantile(0.25)
print(stdd,iqr)
# Out:
# 1033227.5860356417 222891.0

# %%
statsmodels.robust.scale.mad(df['population_total'])
# Out:
# 102516.01300078836

# %%
#percentile and quantile,boxplot,histogram
df['population_total'].quantile([0.05, 0.25, 0.5, 0.75, 0.95])
# Out:
# 0.05     104638.2
# 0.25     126142.0
# 0.50     184133.0
# 0.75     349033.0
# 0.95    1295806.2
# Name: population_total, dtype: float64

# %%
df.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="15d3e2e8-c2fd-4d9d-898c-02d3bb3669d5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("15d3e2e8-c2fd-4d9d-898c-02d3bb3669d5")) {
#                     Plotly.newPlot(
#                         '15d3e2e8-c2fd-4d9d-898c-02d3bb3669d5',
# ...

# %%
df[['population_total']].iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="68ec12ef-343f-4d4f-932f-0dac41df5702" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("68ec12ef-343f-4d4f-932f-0dac41df5702")) {
#                     Plotly.newPlot(
#                         '68ec12ef-343f-4d4f-932f-0dac41df5702',
# ...

# %%
df[['population_total']].iplot(kind='hist')
# Out:
# <div>
#
#
#             <div id="ab2dbe22-36f2-47c8-b6ce-0848b67579b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("ab2dbe22-36f2-47c8-b6ce-0848b67579b6")) {
#                     Plotly.newPlot(
#                         'ab2dbe22-36f2-47c8-b6ce-0848b67579b6',
# ...

# %%
plt.hist(df['population_total'])
# Out:
# (array([469.,  12.,   4.,   3.,   1.,   1.,   1.,   0.,   1.,   1.]),
#  array([  100036. ,  1337877.1,  2575718.2,  3813559.3,  5051400.4,
#          6289241.5,  7527082.6,  8764923.7, 10002764.8, 11240605.9,
#         12478447. ]),
#  <a list of 10 Patch objects>)

# %%
# density estimates
ax = df['population_female'].plot.hist(density=True,bins=4)
df[['population_female']].plot.density(ax=ax)
ax.set_xlabel('population_total (per 100)')
ax

# %%
import pandas as pd
pd_lit = pd.Series([40,58,72,74,74,76,81,83,84,92])
q1 = pd_lit.quantile(0.25)
q2 = pd_lit.quantile(0.50)
q3 = pd_lit.quantile(0.75)
print(q1,q2,q3)
# Out:
# 72.5 75.0 82.5

# %%
#bar graph
df[['name_of_city']].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="5c7b6331-d981-48f9-af3a-0a404d7169db" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c7b6331-d981-48f9-af3a-0a404d7169db")) {
#                     Plotly.newPlot(
#                         '5c7b6331-d981-48f9-af3a-0a404d7169db',
# ...

# %%
df1=df.head()
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8cf0a247f102> in <module>
# ----> 1 df1=df.head()
#       2 df1
#
# NameError: name 'df' is not defined

# %%
df1[['name_of_city']].iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="887ef766-cba2-4b7e-a21f-2c24e6b21296" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("887ef766-cba2-4b7e-a21f-2c24e6b21296")) {
#                     Plotly.newPlot(
#                         '887ef766-cba2-4b7e-a21f-2c24e6b21296',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "name_of_city", "orientation": "v", "text": "", "type": "bar", "x": [0, 1, 2, 3, 4], "y": ["Abohar ", "Achalpur ", "Adilabad ", "Adityapur ", "Adoni "]}],
# ...

# %%
df1=sns.load_dataset('flights')

df1
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# ..    ...        ...         ...
# 139  1960     August         606
# 140  1960  September         508
# 141  1960    October         461
# 142  1960   November         390
# 143  1960   December         432
#
# [144 rows x 3 columns]

# %%
etfs = df1.loc[df1.index>110,df1[df1['month'] == 'may']['year']]
sns.heatmap(etfs.corr(), vmin=-1, vmax=1,cmap=sns.diverging_palette(20, 220, as_cmap=True))
# Out:
# D:\Programdata\lib\site-packages\seaborn\matrix.py:280: UserWarning:
#
# Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#
# D:\Programdata\lib\site-packages\seaborn\matrix.py:280: UserWarning:
#
# Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
df1.plot.hexbin(x='population_male',y='population_female',gridsize=10,figsize=(5,10))

# %%
#contour
ax = sns.kdeplot(df1.year, df1.passengers,color='blue')

# %%
#pandas boxplot
ax = df1.boxplot(by='month', column='passengers')
plt.suptitle('Pd_BOXPLOT')
# Out:
# Text(0.5, 0.98, 'Pd_BOXPLOT')

# %%
#violin plot
ax = sns.violinplot(df1.year, df1.passengers,
inner='quartile', color='red')

# %%
df1
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
#Visualizing Multiple Variables
years = [20,27,28,3]
dff = df.loc[df.state_code.isin(years),:]
def hexbin(x, y, color, **kwargs):
    cmap = sns.light_palette(color='red', as_cmap=True)
    plt.hexbin(x, y, gridsize=15, cmap=cmap, **kwargs)
g = sns.FacetGrid(dff, col='state_code',col_wrap=1)
g.map(hexbin, 'dist_code', 'population_total')

# %%
#Facetgrid
sample_data = pd.DataFrame({
'income': df['population_total'].sample(100),
'type': 'Data'
})
sample_mean_05 = pd.DataFrame({
'income': [df['population_total'].sample(5).mean() for _ in range(100)],
'type': 'Mean of 5',
})
sample_mean_20 = pd.DataFrame({
'income': [df['population_total'].sample(20).mean() for _ in range(100)],
'type': 'Mean of 20',
})
'''
sample_data =df['population_total'].sample(1000,replace=True)
sample_mean_05 =df['population_total'].sample(5)
sample_mean_20 =df['population_total'].sample(20)
'''
results = pd.concat([sample_data, sample_mean_05, sample_mean_20])
g = sns.FacetGrid(results, col='type', col_wrap=1, height=2, aspect=2)
g.map(plt.hist, 'income', range=[0, 200000], bins=40)

# %%
#sklearn resample
results = []
for nrepeat in range(250):
    sample=sklearn.utils.resample(df['population_total'])
    results.append(sample.median())
results = pd.Series(results)
results
# Out:
# 0      180464.0
# 1      180978.0
# 2      194999.0
# 3      194999.0
# 4      179972.0
#          ...
# 245    179972.0
# 246    197662.0
# 247    180464.0
# 248    183383.0
# 249    181624.0
# Length: 250, dtype: float64

# %%
#QQ-Plot of a sample of 100 values drawn from a standard normal distribution
#A QQ-Plot is used to visually determine how close a sample is to a specified distribution, 
#in this case the normal.The QQ-Plot orders the z-scores from low to high, and plots each value’s z-score on the yaxis
fig, ax = plt.subplots(figsize=(4, 4))
norm_sample = stats.norm.rvs(size=100)
stats.probplot(norm_sample, plot=ax)
# Out:
# ((array([-2.46203784, -2.12570747, -1.93122778, -1.79044653, -1.67819304,
#          -1.58381122, -1.50174123, -1.42869743, -1.36256869, -1.30191411,
#          -1.24570419, -1.19317644, -1.14374949, -1.09696931, -1.05247413,
#          -1.00997067, -0.96921765, -0.93001393, -0.89218993, -0.85560121,
#          -0.82012357, -0.78564937, -0.75208458, -0.71934648, -0.68736185,
#          -0.65606548, -0.62539893, -0.59530962, -0.56574992, -0.53667655,
#          -0.50804994, -0.47983378, -0.45199463, -0.42450149, -0.39732558,
#          -0.37044003, -0.34381966, -0.31744076, -0.29128096, -0.26531902,
#          -0.23953472, -0.21390872, -0.18842244, -0.16305799, -0.13779803,
#          -0.1126257 , -0.08752455, -0.06247843, -0.03747145, -0.01248789,
#           0.01248789,  0.03747145,  0.06247843,  0.08752455,  0.1126257 ,
#           0.13779803,  0.16305799,  0.18842244,  0.21390872,  0.23953472,
#           0.26531902,  0.29128096,  0.31744076,  0.34381966,  0.37044003,
# ...
